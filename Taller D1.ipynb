# %% [markdown]
# # Taller 1
#
# ## Instructor: Katherine Morales

# %%
# Este comentario 
# 6+5
5+5
# Out:
# 10

# %% [markdown]
# Asiganción / Actualización

# %%
 a = 5 +10

# %%
a = a + 2

# %%
a
# Out:
# 17

# %% [markdown]
# Expressión

# %%
10+5
# Out:
# 15

# %% [markdown]
# Sensibilidad a mayúsculas y minúsculas

# %%
a = 10

# %%
A = 2

# %%
a
# Out:
# 10

# %%
A
# Out:
# 2

# %%
2 + 3*5
# Out:
# 17

# %%
2*3
# Out:
# 6

# %%
2**3#potencia
# Out:
# 8

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# Librerías
# math
#
#
# intallation
#
# conda (pip/pip3) install paquete

# %%
import math# cargar 

math.floor(2.3)
# Out:
# 2

# %%
#Librerías  que vamps a usar

import os 
import math
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Estructuras de datos | Objetos

# %%
a  = "Taller 1"

# %%
a.__class__
# Out:
# str

# %%
b =  5
b.__class__
# Out:
# int

# %%
lista1 = [  1,4,5  ]
lista1.__class__
# Out:
# list

# %%
s1  = pd.Series([11,25])
s1
# Out:
# 0    11
# 1    25
# dtype: int64

# %%
s1.__class__
# Out:
# pandas.core.series.Series

# %%
l1 = [ 1, 4 ,5  ]

# %%
b2 = 5.5
type(b2)
# Out:
# float

# %%
l2 = ['hola', 'SEE']

# %%
l1 + l2
# Out:
# [1, 4, 5, 'hola', 'SEE']

# %%
s1  = pd.Series([11,25, '5,5'])
s1
# Out:
# 0          11
# 1          25
# 2    sin info
# dtype: object

# %% [markdown]
# [11, 25, nan]

# %%
Nombre = ['Katherine', 'Tania']
Edad = [26, 27]
Ciudad = ['Quito', 'Guayaquil']
df = pd.DataFrame({
    'N': Nombre,
    'E': Edad,
    'C': Ciudad 
})

# %%
df = pd.DataFrame({
    'N': Nombre,
    'E': Edad,
    'C': Ciudad 
})

# %%
df
# Out:
#            N   E          C
# 0  Katherine  26      Quito
# 1      Tania  27  Guayaquil

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   N       2 non-null      object
#  1   E       2 non-null      int64
#  2   C       2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %%
df.rename( columns= { 'N': 'Nombre', 'E': 'Edad', 'C': 'Ciudad' }  )
# Out:
#       Nombre  Edad     Ciudad
# 0  Katherine    26      Quito
# 1      Tania    27  Guayaquil

# %%
df
# Out:
#            N   E          C
# 0  Katherine  26      Quito
# 1      Tania  27  Guayaquil

# %%
df = df.rename( columns= { 'N': 'Nombre', 'E': 'Edad', 'C': 'Ciudad' }  )

# %%
df.rename( columns= { 'N': 'Nombre', 'E': 'Edad', 'C': 'Ciudad' }  , inplace=True)

# %%
df
# Out:
#       Nombre  Edad     Ciudad
# 0  Katherine    26      Quito
# 1      Tania    27  Guayaquil

# %%
df.describe()#describe sin ningún parámetro solo me permite usa variables numéricas
# Out:
#             Edad
# count   2.000000
# mean   26.500000
# std     0.707107
# min    26.000000
# 25%    26.250000
# 50%    26.500000
# 75%    26.750000
# max    27.000000

# %%
df.describe(include='all')
# Out:
#        Nombre       Edad Ciudad
# count       2   2.000000      2
# unique      2        NaN      2
# top     Tania        NaN  Quito
# freq        1        NaN      1
# mean      NaN  26.500000    NaN
# std       NaN   0.707107    NaN
# min       NaN  26.000000    NaN
# 25%       NaN  26.250000    NaN
# 50%       NaN  26.500000    NaN
# 75%       NaN  26.750000    NaN
# max       NaN  27.000000    NaN

# %%
df.dtypes
# Out:
# Nombre    object
# Edad       int64
# Ciudad    object
# dtype: object
